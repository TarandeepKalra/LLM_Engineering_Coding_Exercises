# %%
# imports

import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()

# %%
# Step 1: Create your prompts

system_prompt = """ 
You are a helpful assistant that helps me summarize the overall discussion in an Email Thread.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

my_name = "Priya Singh"

user_prompt_prefix = """
I am providing my name here. Also I am providing the contents of the entire Email thread. Summarize the overall discussion, the recent updates and the next action items.
If there is something asked specifically from me in the most recent 3 Emails, highlight that so I can take the appropriate action.
"""

# Content of the email thread

email_thread = """

From: Rahul Mehta [rahul.mehta@example.com](mailto:rahul.mehta@example.com)
To: Priya Singh [priya.singh@example.com](mailto:priya.singh@example.com), John Carter [john.carter@example.com](mailto:john.carter@example.com), Ayesha Khan [ayesha.khan@example.com](mailto:ayesha.khan@example.com), Liam O’Connor [liam.oconnor@example.com](mailto:liam.oconnor@example.com)
Date: Mon, 12 Jan 2026 09:14 AM

Hi everyone,

Did you see the ICC T20 World Cup 2026 schedule announcement? Looks like the tournament will be hosted jointly by India and Sri Lanka. Excited to see how the pitches will behave this time.

Rahul

---

From: Priya Singh [priya.singh@example.com](mailto:priya.singh@example.com)
To: Rahul Mehta [rahul.mehta@example.com](mailto:rahul.mehta@example.com), John Carter [john.carter@example.com](mailto:john.carter@example.com), Ayesha Khan [ayesha.khan@example.com](mailto:ayesha.khan@example.com), Liam O’Connor [liam.oconnor@example.com](mailto:liam.oconnor@example.com)
Date: Mon, 12 Jan 2026 10:02 AM

Hi Rahul and team,

Yes, I saw it! India playing the opening match in Mumbai is huge. Also interesting that Bangladesh didn’t qualify directly this time. That surprised me.

Priya

---

From: John Carter [john.carter@example.com](mailto:john.carter@example.com)
To: Priya Singh [priya.singh@example.com](mailto:priya.singh@example.com), Rahul Mehta [rahul.mehta@example.com](mailto:rahul.mehta@example.com), Ayesha Khan [ayesha.khan@example.com](mailto:ayesha.khan@example.com), Liam O’Connor [liam.oconnor@example.com](mailto:liam.oconnor@example.com)
Date: Mon, 12 Jan 2026 11:30 AM

> Also interesting that Bangladesh didn’t qualify directly this time.

I read they failed in the regional qualifiers, which is a big upset. Meanwhile, USA and Canada made it in again—great for North American cricket visibility.

John

---

From: Ayesha Khan [ayesha.khan@example.com](mailto:ayesha.khan@example.com)
To: John Carter [john.carter@example.com](mailto:john.carter@example.com), Priya Singh [priya.singh@example.com](mailto:priya.singh@example.com), Rahul Mehta [rahul.mehta@example.com](mailto:rahul.mehta@example.com), Liam O’Connor [liam.oconnor@example.com](mailto:liam.oconnor@example.com)
Date: Tue, 13 Jan 2026 08:45 AM

> USA and Canada made it in again

That’s exciting! Pakistan’s squad is still uncertain though—there’s talk of resting senior players and focusing on younger talent. Could be risky.

Ayesha

---

From: Liam O’Connor [liam.oconnor@example.com](mailto:liam.oconnor@example.com)
To: Ayesha Khan [ayesha.khan@example.com](mailto:ayesha.khan@example.com), John Carter [john.carter@example.com](mailto:john.carter@example.com), Priya Singh [priya.singh@example.com](mailto:priya.singh@example.com), Rahul Mehta [rahul.mehta@example.com](mailto:rahul.mehta@example.com)
Date: Tue, 13 Jan 2026 09:10 AM

> Pakistan’s squad is still uncertain

Australia is in a similar situation. Some senior players may retire before 2026. Also, I’m curious how Sri Lanka’s home advantage will play out in group matches.

Liam

---

From: Rahul Mehta [rahul.mehta@example.com](mailto:rahul.mehta@example.com)
To: Liam O’Connor [liam.oconnor@example.com](mailto:liam.oconnor@example.com), Ayesha Khan [ayesha.khan@example.com](mailto:ayesha.khan@example.com), John Carter [john.carter@example.com](mailto:john.carter@example.com), Priya Singh [priya.singh@example.com](mailto:priya.singh@example.com)
Date: Wed, 14 Jan 2026 07:55 AM

Thanks all—interesting points. I think this World Cup will be very unpredictabl


"""

# Step 2: Make the messages list

messages = [
    {"role" : "system", "content" : system_prompt},
    {"role" : "user", "content" : user_prompt_prefix + my_name + email_thread}
] 

# Step 3: Call OpenAI
response = openai.chat.completions.create(
    model = "gpt-4.1-mini",
    messages = messages)

# Step 4: print the result
display(Markdown(response.choices[0].message.content))
# Out:
# # Email Thread Summary
#
# **Overall Discussion:**
# The email thread revolves around the announcement and discussion of the ICC T20 World Cup 2026 schedule, which will be co-hosted by India and Sri Lanka. The team members are sharing their thoughts on the schedule, venue, and implications for various cricket teams participating in the tournament.
#
# **Recent Updates:**
# - The tournament will be jointly hosted by India and Sri Lanka.
# - India will play the opening match in Mumbai.
# - Bangladesh did not qualify directly for the tournament, which was a surprise.
# - USA and Canada qualified again, enhancing North American cricket visibility.
# - Pakistan is considering resting senior players and bringing in younger talent, which may be risky.
# - Australia is facing uncertainty due to possible retirements of senior players before the tournament.
# - There is curiosity about how Sri Lanka’s home advantage might influence the group stage matches.
# ...
